# %%
import tweepy

# BEARER = 'AAAAAAAAAAAAAAAAAAAAAL2YRwEAAAAAraFZWowkSnaEod0vV6U4lKhHgwk%3DPom9PWdKzESnZqnLStCkAxZ0vHS8QnLnExi6rEaH6PPSQ9oie6'

twitter_keys = {
    'consumer_key': 'xsLmIoXBMS5AyP9ApgjlVDutz',
    'consumer_secret': 'efjjVQrGOZfMQwNSZPXXAbEp0YpTBgvDUvzgwzy3dlJzcZqxMU',
    'access_token_key': '841044884048007170-QFO951QfYWjL4YjJVQ5oIV56b3BWKWy',
    'access_token_secret': '7VYCyHDZ79GfU1KcKrAG281ua453PWIG0yIBHw01GZx3l'
}

# %%
auth = tweepy.OAuthHandler(twitter_keys['consumer_key'], twitter_keys['consumer_secret'])
auth.set_access_token(twitter_keys['access_token_key'], twitter_keys['access_token_secret'])
api = tweepy.API(auth)

#Faz a chamada da sua timeline e imprime cada texto dos tweets
public_tweets = api.home_timeline()
for tweet in public_tweets:
  print(tweet.text)
# Out:
# Quadrakill do pai #PokemonUNITE #NintendoSwitch https://t.co/m73zribFlq
# RT @Twisterfps: Gameday vs Liquid as 15h 🙏
# #diadefuria https://t.co/vsRcbrikEZ
# RT @StreetArtUtopia: EcoMask – Rémi Gaillard and Dr. Love
# https://t.co/pl7PN8N3Qe https://t.co/TjvAgqOtYd
# não vou sentir um pingo de dó do seu coração, lembra oq fez cmg ou já se esqueceu??
# dois aniversário td find, já não sei onde catar dinheiro
# 8 anos atrás no dia de hj nóis tava como fml? 😎 https://t.co/z4VVFXyIMR
# They sent a billionaire into space on a rocket shaped like a dick.
# RT @djjohnso: Posted via @ESN_TO Insta.
#
# SUPER IMPORTANT https://t.co/N8kqBI0yNY
# Pode-se fazer muitas críticas ao Felipe Neto, mas um cara com a grana e influência que tem poderia simplesmente ter… https://t.co/ZvKIQyNN7p
# Nossa esperança é que o próximo governo tenha um bom projeto de desenvolvimento do país e que a gente realize mais… https://t.co/3IZFziNsjI
# Os efeitos de um governo que ignorou a pandemia e sugeriu remédio ineficaz e vacina com propina ao invés de fazer o… https://t.co/h2cOsyzLrG
# Dólar caiu ☺️ - R$ 5,23 às 12:50
#
# Variação 📈 +0,17% (R$ 0,01)
# RT @geglobo: Quem é Gaules? A história do streamer brasileiro de sucesso 🎮 https://t.co/bpRbzJwOpn
# Todo dia isso 😥 https://t.co/PMV2QUNnth
# A Cinemark é líder mundial em venda de ingressos, responsável por cerca de 30% do mercado brasileiro, com mais de 6… https://t.co/lRnizilnaV
# Vamos oferecer 5% de cashback na compra de ingressos e assim garantir a presença do Méliuz em todas as sessões de cinema da rede.
# Feliz em anunciar mais uma parceria exclusiva: desta vez com a Cinemark. #CASH3 https://t.co/Z1qrNExZ0G

# %%
import json
status = public_tweets[0]
#convert to string
json_str = json.dumps(status._json)
#deserialise string into python object
parsed = json.loads(json_str)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Wed Jul 21 16:38:23 +0000 2021",
#     "entities": {
#         "hashtags": [
#             {
#                 "indices": [
#                     18,
#                     31
#                 ],
#                 "text": "PokemonUNITE"
#             },
#             {
#                 "indices": [
#                     32,
#                     47
#                 ],
#                 "text": "NintendoSwitch"
#             }
#         ],
#         "media": [
#             {
#                 "display_url": "pic.twitter.com/m73zribFlq",
#                 "expanded_url": "https://twitter.com/14barp/status/1417886684293734407/video/1",
#                 "id": 1417886630363373570,
#                 "id_str": "1417886630363373570",
#                 "indices": [
#                     48,
#                     71
#                 ],
#                 "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1417886630363373570/pu/img/7YjvSBJPaTN-mkMu.jpg",
#                 "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1417886630363373570/pu/img/7YjvSBJPaTN-mkMu.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 720,
#                         "resize": "fit",
#                         "w": 1280
#                     },
#                     "medium": {
#                         "h": 675,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 383,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "photo",
#                 "url": "https://t.co/m73zribFlq"
#             }
#         ],
#         "symbols": [],
#         "urls": [],
#         "user_mentions": []
#     },
#     "extended_entities": {
#         "media": [
#             {
#                 "additional_media_info": {
#                     "monetizable": false
#                 },
#                 "display_url": "pic.twitter.com/m73zribFlq",
#                 "expanded_url": "https://twitter.com/14barp/status/1417886684293734407/video/1",
#                 "id": 1417886630363373570,
#                 "id_str": "1417886630363373570",
#                 "indices": [
#                     48,
#                     71
#                 ],
#                 "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1417886630363373570/pu/img/7YjvSBJPaTN-mkMu.jpg",
#                 "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1417886630363373570/pu/img/7YjvSBJPaTN-mkMu.jpg",
#                 "sizes": {
#                     "large": {
#                         "h": 720,
#                         "resize": "fit",
#                         "w": 1280
#                     },
#                     "medium": {
#                         "h": 675,
#                         "resize": "fit",
#                         "w": 1200
#                     },
#                     "small": {
#                         "h": 383,
#                         "resize": "fit",
#                         "w": 680
#                     },
#                     "thumb": {
#                         "h": 150,
#                         "resize": "crop",
#                         "w": 150
#                     }
#                 },
#                 "type": "video",
#                 "url": "https://t.co/m73zribFlq",
#                 "video_info": {
#                     "aspect_ratio": [
#                         16,
#                         9
#                     ],
#                     "duration_millis": 29500,
#                     "variants": [
#                         {
#                             "content_type": "application/x-mpegURL",
#                             "url": "https://video.twimg.com/ext_tw_video/1417886630363373570/pu/pl/pNPfpJk5EoN60sN9.m3u8?tag=12&container=fmp4"
#                         },
#                         {
#                             "bitrate": 2176000,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/ext_tw_video/1417886630363373570/pu/vid/1280x720/8NfDGhshE0I8dfLn.mp4?tag=12"
#                         },
#                         {
#                             "bitrate": 256000,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/ext_tw_video/1417886630363373570/pu/vid/480x270/znIJ1blnCQmjEkGp.mp4?tag=12"
#                         },
#                         {
#                             "bitrate": 832000,
#                             "content_type": "video/mp4",
#                             "url": "https://video.twimg.com/ext_tw_video/1417886630363373570/pu/vid/640x360/b8nHXsIyGMsdElT6.mp4?tag=12"
#                         }
#                     ]
#                 }
#             }
#         ]
#     },
#     "favorite_count": 1,
#     "favorited": false,
#     "geo": null,
#     "id": 1417886684293734407,
#     "id_str": "1417886684293734407",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "possibly_sensitive_appealable": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"https://www.nintendo.com/countryselector\" rel=\"nofollow\">Nintendo Switch Share</a>",
#     "text": "Quadrakill do pai #PokemonUNITE #NintendoSwitch https://t.co/m73zribFlq",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu May 27 16:26:23 +0000 2021",
#         "default_profile": true,
#         "default_profile_image": false,
#         "description": "Eu vim do Cairo \ud83c\udfdb \u2022 29/09",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 402,
#         "follow_request_sent": false,
#         "followers_count": 27,
#         "following": true,
#         "friends_count": 239,
#         "geo_enabled": false,
#         "has_extended_profile": true,
#         "id": 1397952308772802562,
#         "id_str": "1397952308772802562",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": null,
#         "listed_count": 0,
#         "location": "",
#         "name": "JO\u00c3O",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/1397952308772802562/1624455708",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1417074291561086981/0Zxp6YoP_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1417074291561086981/0Zxp6YoP_normal.jpg",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "14barp",
#         "statuses_count": 135,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false,
#         "withheld_in_countries": []
#     }
# }
